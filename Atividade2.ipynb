# %% [markdown]
# # Aula 20/03
# Kariny e Wandra
#
# Primeira Função - Com restrição de igualdade
# g11: x1² + (x2 - 1)²
# A solução ótima x∗ = (−0.707036070037170616, 0.500000004333606807)
# f (x∗) = 0.7499.

# %%
import random

def g11(x1, x2):
    return x1**2 + (x2 - 1)**2

# restrição: (x2 - x1²) = 0
def h1(x1, x2):
    return abs(x2 - x1**2)

def main():
    array_minimum = []
    for x in range(10000):
        x1 = random.uniform(-1, 1)
        x2 = random.uniform(-1, 1)
        y = g11(x1, x2)
        y_h1 = h1(x1, x2)

        if y_h1 > 10e-6:
            y += y_h1

        array_minimum.append((x1, x2, y))

    melhor = array_minimum[0]
    for t in array_minimum:
        if t[2] < melhor[2]:
            melhor = t
    print(melhor)

main()
# Out:
# (-0.3693935606903114, 0.4999916396548505, 0.7500000000698953)

# %% [markdown]
# Função multi objetivo - sem restrição
# f2: sin⁶(5πx)

# %%
import random
import math

def f2(x1):
    return math.sin(5 * math.pi * x1)**6

def main():
    array_minimum = []
    for x in range(10000):
        x1 = random.uniform(0, 1)
        y = f2(x1)

        array_minimum.append((x1, y))

    melhor = array_minimum[0]
    for t in array_minimum:
        if t[1] < melhor[1]:
            melhor = t
    print(melhor)

main()
# Out:
# (0.3999989726238925, 1.7664283727124688e-29)

# %% [markdown]
# Função multi objetivo - sem restrição - com gráfico

# %%
import random
import math
import matplotlib.pyplot as plt

def f2(x1):
    return math.sin(5 * math.pi * x1) ** 6

def main():
    array_minimum = []
    xs = []
    ys = []

    for _ in range(10000):
        x1 = random.uniform(0, 1)
        y = f2(x1)

        xs.append(x1)
        ys.append(y)
        array_minimum.append((x1, y))

    melhor = array_minimum[0]
    for t in array_minimum:
        if t[1] < melhor[1]:
            melhor = t

    print("Melhor ponto:", melhor)

    plt.scatter(xs, ys, s=5, alpha=0.5, label="Pontos aleatórios")

    plt.scatter(melhor[0], melhor[1], color='red', s=100, label="Melhor ponto")

    plt.xlabel("x")
    plt.ylabel("f(x)")
    plt.title("Busca aleatória do mínimo")
    plt.legend()
    plt.show()

main()
# Out:
# Melhor ponto: (0.1999690243124752, 1.3269204487781659e-20)
